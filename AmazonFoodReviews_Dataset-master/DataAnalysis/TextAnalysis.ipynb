# %%
#Run this with >bokeh serve --show TextAnalysis.ipynb
import pandas as pd
import numpy as np
from collections import Counter
import warnings
warnings.filterwarnings("ignore")
from bokeh.io import curdoc,curstate
from bokeh.layouts import widgetbox
import time

from bokeh.layouts import layout,column,row
from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource,Slider
from bokeh.palettes import Spectral6

from bokeh.models.widgets import Panel, Tabs
from bokeh.models.callbacks import CustomJS

# %%
from bokeh.io import output_notebook, push_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5a98edb9-3cae-4252-a4c7-24c7530a46e0">Loading BokehJS ...</span>
#     </div>

# %%
reviews=pd.read_csv('./Reviews.csv')
text_df=reviews[['Summary','Text']]
text_df.head()
# Out:
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
summary=text_df['Summary'].tolist()
text=text_df['Text'].tolist()
print("Num records:",len(summary))

def tokenize(sentence):
    return str(sentence).split()

summary_tokens=list(map(tokenize,summary[:50000]))
text_tokens=list(map(tokenize,text[:50000]))
print("Num records tokens:",len(summary_tokens),len(text_tokens))

summary_tokens_len=list(map(len,summary_tokens))
text_tokens_len=list(map(len,text_tokens))
# Out:
# Num records: 568454
# Num records tokens: 50000 50000

# %%
plot = figure(title="TextAnalysis",tools="save,hover,pan",width=400,height=400,
            background_fill_color="#E8DDCB")

hist, edges = np.histogram(text_tokens_len, density=True, bins=50)
plot.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
plot.legend.location = "center_right"
plot.legend.background_fill_color = "darkgrey"
plot.xaxis.axis_label = 'x'
plot.yaxis.axis_label = 'Count(x)'

plot2 = figure(title="SumaryAnalysis",tools="save,hover,pan",width=400,height=400,
            background_fill_color="#E8DDCB")

hist, edges = np.histogram(summary_tokens_len, density=True, bins=50)
plot2.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
plot2.legend.location = "center_right"
plot2.legend.background_fill_color = "darkgrey"
plot2.xaxis.axis_label = 'x'
plot2.yaxis.axis_label = 'Count(x)'

show(row(plot,plot2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e47456ec-3d73-4f75-b7db-c5cbcede6cfe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e47456ec-3d73-4f75-b7db-c5cbcede6cfe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e47456ec-3d73-4f75-b7db-c5cbcede6cfe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e47456ec-3d73-4f75-b7db-c5cbcede6cfe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"30ccf325-917b-4a67-a2e7-caba0ed53005":{"roots":{"references":[{"attributes":{},"id":"efae6702-b451-4ddd-b921-3aa1686b4fe8","type":"BasicTicker"},{"attributes":{"plot":{"id":"196a7760-cd90-40cf-bf3f-117123f5d76c","subtype":"Figure","type":"Plot"}},"id":"23677acd-ae02-4b99-a2c8-d30e83c3509b","type":"SaveTool"},{"attributes":{"axis_label":"Count(x)","formatter":{"id":"66dd27c1-e1e3-4a31-b2d3-46bd6504f031","type":"BasicTickFormatter"},"plot":{"id":"196a7760-cd90-40cf-bf3f-117123f5d76c","subtype":"Figure","type":"Plot"},"ticker":{"id":"efae6702-b451-4ddd-b921-3aa1686b4fe8","type":"BasicTicker"}},"id":"8b8cfe23-d244-4300-bf81-67da6c248cb3","type":"LinearAxis"},{"attributes":{},"id":"66dd27c1-e1e3-4a31-b2d3-46bd6504f031","type":"BasicTickFormatter"},{"attributes":{},"id":"8db2b124-721b-4222-a154-35fc33d5d616","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"196a7760-cd90-40cf-bf3f-117123f5d76c","subtype":"Figure","type":"Plot"},"ticker":{"id":"efae6702-b451-4ddd-b921-3aa1686b4fe8","type":"BasicTicker"}},"id":"fb82bf9b-ccb9-41f9-85f6-8dda3934a6ce","type":"Grid"},{"attributes":{"data_source":{"id":"aae3029f-1e50-41e3-a5d1-c1e9c6e90fcd","type":"ColumnDataSource"},"glyph":{"id":"15f2ce2c-c31b-4caf-8496-1771e60d394b","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1b73b2ac-e19c-4ee7-9187-a57590758304","type":"Quad"},"selection_glyph":null},"id":"7e99059e-6612-49c5-8ade-638f38e0ca1d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"196a7760-cd90-40cf-bf3f-117123f5d76c","subtype":"Figure","type":"Plot"}},"id":"80440f7f-a68c-4e5a-b097-da1269e55a77","type":"PanTool"},{"attributes":{"callback":null},"id":"ab4109ac-8bc4-42bf-9a81-e4f796c6a85b","type":"DataRange1d"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"8a961187-0865-4009-8c12-2894c94653d8","type":"Quad"},{"attributes":{"callback":null,"plot":{"id":"196a7760-cd90-40cf-bf3f-117123f5d76c","subtype":"Figure","type":"Plot"}},"id":"04b2ed39-3420-4c08-af7b-2cd4332547a8","type":"HoverTool"},{"attributes":{},"id":"64e47425-2b8e-41ea-bb40-4aef3d3a79b8","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1b73b2ac-e19c-4ee7-9187-a57590758304","type":"Quad"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"29e9e7ba-0824-410a-aa89-9fd6a6e63d4a","type":"LinearAxis"}],"left":[{"id":"4e9ffa5e-cbe8-458c-b77d-8647ab535e60","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"29e9e7ba-0824-410a-aa89-9fd6a6e63d4a","type":"LinearAxis"},{"id":"345235c1-87cf-4a52-bdbc-9519c653ee4a","type":"Grid"},{"id":"4e9ffa5e-cbe8-458c-b77d-8647ab535e60","type":"LinearAxis"},{"id":"97d55d7a-4c13-4316-a429-09296e7716df","type":"Grid"},{"id":"56346996-dd37-478a-ad72-081e4b657cc5","type":"GlyphRenderer"}],"title":{"id":"1557ea68-93ff-43ee-8245-0784c0702d08","type":"Title"},"tool_events":{"id":"dbbbbf29-3385-4867-b5d3-9efe55b0cff2","type":"ToolEvents"},"toolbar":{"id":"6c530845-0b4f-450a-8a66-baf653451cf3","type":"Toolbar"},"x_range":{"id":"ab4109ac-8bc4-42bf-9a81-e4f796c6a85b","type":"DataRange1d"},"y_range":{"id":"988ebd09-4309-49ef-8511-446cf8ad7152","type":"DataRange1d"}},"id":"a367bfb4-b9ee-44ff-b7f3-737d67807736","subtype":"Figure","type":"Plot"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"75c923b8-d5a9-411f-9497-13525efd72b6","type":"LinearAxis"}],"left":[{"id":"8b8cfe23-d244-4300-bf81-67da6c248cb3","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"75c923b8-d5a9-411f-9497-13525efd72b6","type":"LinearAxis"},{"id":"17fd18c4-b425-49f0-9454-0657355801d1","type":"Grid"},{"id":"8b8cfe23-d244- ...

# %%
#Apply a slider widget that controls the number of records to use.
#Best done with holoviews dynamic maps.
def get_text_counts(n_docs=10000):
    global summary,text
    summary_tokens=list(map(tokenize,summary[:n_docs]))
    text_tokens=list(map(tokenize,text[:n_docs]))
    summary_dict=Counter(list(map(len,summary_tokens)))
    text_dict=Counter(list(map(len,text_tokens)))
    
    return dict(text_idx=text_dict.keys(),text_counts=text_dict.values(),\
               summary_idx=summary_dict.keys(),summary_counts=summary_dict.values())

slider=None
tabs=None

def update_plot(attr,old,new):
    global tabs,slider,source
    txt_sum=tabs.active
    print("Active= ",txt_sum)
    
    n_docs=slider.value
    data=get_text_counts(n_docs=n_docs)
    if(txt_sum==0):
        source.data=dict(idx=list(data['text_idx']),counts=list(data['text_counts']),\
                        summary_idx=list(data['summary_idx']),summary_counts=list(data['summary_counts']),\
                        text_idx=list(data['text_idx']),text_counts=list(data['text_counts']))
    else:
        source.data=dict(idx=list(data['summary_idx']),counts=list(data['summary_counts']),\
                        summary_idx=list(data['summary_idx']),summary_counts=list(data['summary_counts']),\
                        text_idx=list(data['text_idx']),text_counts=list(data['text_counts']))
        
        
        
source=ColumnDataSource(data=dict(test_idx=[],test_counts=[],\
                                   summary_idx=[],summary_counts=[],\
                                   idx=[],counts=[]))        
    
callback = CustomJS(args=dict(source=source), code="""
        var data = source.data;
        var f = cb_obj.value
        
        x = data['idx']
        y = data['counts']

        if(f==0)
           {
             x=source.data['text_idx']
             y=source.data['text_counts']
           }
         else{
             x=source.data['summary_idx']
             y=source.data['summary_counts'] 
         }  
        source.change.emit();
    """)
        


slider = Slider(start=1000, end=100000, value=1000, step=1000,
                    title="Number of docs", orientation='horizontal')

slider.on_change('value',update_plot)
p1 = figure( plot_height=350, toolbar_location='above', title="Text Counts")
p1.vbar(x='idx', top='counts', width=0.9, source=source, legend="Counts",
       line_color='red')

p1.xgrid.grid_line_color = None
#p1.y_range.start = 0
#p1.y_range.end = 9
p1.legend.orientation = "horizontal"
p1.legend.location = "top_left"
tab1 = Panel(child=p1, title="Text")

p2 = figure( plot_height=350, toolbar_location='above', title="Summary Counts")
p2.vbar(x='idx', top='counts', width=0.9, source=source, legend="Counts",
       line_color='blue')

p2.xgrid.grid_line_color = None
#p2.y_range.start = 0
#p2.y_range.end = 9
p2.legend.orientation = "horizontal"
p2.legend.location = "top_left"
tab2 = Panel(child=p2, title="Summary")


tabs=Tabs(tabs=[tab1,tab2],callback=callback)

plot=row(tabs,widgetbox(slider))
curdoc().add_root(plot)

# %%
from ipywidgets import interact

def update(s):
    global tabs,source
    txt_sum=tabs.active
    print("Active= ",txt_sum)
    
    n_docs=s
    data=get_text_counts(n_docs=n_docs)
    if(txt_sum==0):
        source.data=dict(idx=list(data['text_idx']),counts=list(data['text_counts']),\
                        summary_idx=list(data['summary_idx']),summary_counts=list(data['summary_counts']),\
                        text_idx=list(data['text_idx']),text_counts=list(data['text_counts']))
    else:
        source.data=dict(idx=list(data['summary_idx']),counts=list(data['summary_counts']),\
                        summary_idx=list(data['summary_idx']),summary_counts=list(data['summary_counts']),\
                        text_idx=list(data['text_idx']),text_counts=list(data['text_counts']))
        
    push_notebook()

show(plot,notebook_handle=True)    
interact(update,s=(1000,100000,1000))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7279396a-b8e6-4489-a981-fa882a7d7f9a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7279396a-b8e6-4489-a981-fa882a7d7f9a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("d85e800c-86b0-44f3-8e00-b8eee22e6109", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7279396a-b8e6-4489-a981-fa882a7d7f9a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7279396a-b8e6-4489-a981-fa882a7d7f9a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"48877899-d23f-49dc-a457-62836319ba80":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"blue"},"top":{"field":"counts"},"width":{"value":0.9},"x":{"field":"idx"}},"id":"dd4967bd-8a4e-49cf-aaf0-fa63ede2b100","type":"VBar"},{"attributes":{"callback":null,"column_names":["test_idx","test_counts","summary_idx","summary_counts","idx","counts"],"data":{"counts":[],"idx":[],"summary_counts":[],"summary_idx":[],"test_counts":[],"test_idx":[]}},"id":"84bad75c-029f-4ab8-9fee-a9efdda0f006","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"0d865225-2d83-4872-9220-0ab117022695","type":"DataRange1d"},{"attributes":{},"id":"4a146ac3-6d27-4e97-b687-30f25d7e1054","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"red"},"top":{"field":"counts"},"width":{"value":0.9},"x":{"field":"idx"}},"id":"94cee729-e9e4-4855-85d8-6a04b8aa2538","type":"VBar"},{"attributes":{},"id":"c6e1599e-e2a1-43be-84c6-48631a220809","type":"BasicTicker"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"aa83b5f4-6cf7-4049-b79a-beb704de10bf","subtype":"Figure","type":"Plot"},"ticker":{"id":"19bb1847-a2b1-40e1-9095-372d19e2ec98","type":"BasicTicker"}},"id":"a9d185e8-eb2f-492c-8dfb-6d34ef4c94de","type":"Grid"},{"attributes":{"callback":{"id":"81653276-50ec-4b0a-84af-1a74f48eb263","type":"CustomJS"},"tabs":[{"id":"4785693d-a76b-4e5b-bde9-b1c67bb6c57a","type":"Panel"},{"id":"75fbf633-7a1e-402d-abfd-17a514c707a1","type":"Panel"}]},"id":"19c59713-9871-40e3-8e2b-4b8ebde37cd2","type":"Tabs"},{"attributes":{},"id":"d1681893-a870-464d-bde9-d1bde9b72612","type":"ToolEvents"},{"attributes":{"callback":null},"id":"4335c362-59ed-460c-b6eb-bec8576547ac","type":"DataRange1d"},{"attributes":{},"id":"a87125b5-30f6-4253-a849-2c2a74185791","type":"BasicTickFormatter"},{"attributes":{},"id":"19bb1847-a2b1-40e1-9095-372d19e2ec98","type":"BasicTicker"},{"attributes":{"callback":null},"id":"4c442a1a-5920-427e-b5d3-cfdb86a0a4bb","type":"DataRange1d"},{"attributes":{"plot":{"id":"aa83b5f4-6cf7-4049-b79a-beb704de10bf","subtype":"Figure","type":"Plot"}},"id":"77bad8ca-8cad-43c6-9e30-642c40cf9097","type":"PanTool"},{"attributes":{},"id":"bec5190e-1989-49e3-9711-994618ad4827","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8e300f1a-1d1d-4f14-9b99-be7d2d7e661c","type":"PanTool"},{"id":"d568845c-e303-4045-aafc-b5b6d00f5ee8","type":"WheelZoomTool"},{"id":"e1717b76-290a-4654-8fbb-fc91b229b9b7","type":"BoxZoomTool"},{"id":"d20af191-cfb4-471c-8142-9680bb46a1e5","type":"SaveTool"},{"id":"ac3b10e8-393b-48b8-b321-59d40a9bb02d","type":"ResetTool"},{"id":"b6b3cb87-ff84-42a0-90db-9cf7cd31d67a","type":"HelpTool"}]},"id":"b15c7dde-b0e2-4a53-87cb-30366bfcfa76","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"counts"},"width":{"value":0.9},"x":{"field":"idx"}},"id":"adf31c79-6bea-4f57-8fed-5c8cff02ed16","type":"VBar"},{"attributes":{"plot":null,"text":"Summary Counts"},"id":"38fcf4f6-13b2-4d88-9bbb-6e264d0fd1a7","type":"Title"},{"attributes":{"below":[{"id":"58eea444-5223-4037-8f3d-f952ff9a1aa2","type":"LinearAxis"}],"left":[{"id":"05c1a523-d0e3-4766-95c6-8eef39daab85","type":"LinearAxis"}],"plot_height":350,"renderers":[{"id":"58eea444-5223-4037-8f3d-f952ff9a1aa2","type":"LinearAxis"},{"id":"de4e2eb2-c85c-48de-a199-f07879ac2ab9","type":"Grid"},{"id":"05c1a523-d0e3-4766-95c6-8eef39daab85","type":"LinearAxis"},{"id":"01cf9e1c-4d53-4b72-8117-367055b84896","type":"Grid"},{"id":"2a564d58-47c2-4244-b19c-69e3b4208a93","type":"BoxAnnotation"},{"id":"e44644f2-9e80-4852-83b1-26c54e1d3839","type":"Legend"},{"id":"bb53a421-c192-42c3-be32-e448ac499738","type":"GlyphRenderer"}],"title":{"id":"38fcf4f6-13b2-4d88-9bbb-6e264d0fd1a7","type":"Title"},"tool_events":{"id":"fadfc830-6fcf-4fce-839b-8bda9ce8 ...
# <function __main__.update>
