# %%
import pandas as pd
import numpy as np
import pickle

from bokeh.plotting import figure, show
from bokeh.layouts import layout,column,row
from bokeh.models import ColumnDataSource,Slider


from bokeh.io import curdoc,curstate
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Select

import warnings
warnings.filterwarnings("ignore")

from bokeh.models.formatters import CategoricalTickFormatter
from bokeh.models.mappers import CategoricalColorMapper
from bokeh.models import (
    HoverTool,
    LinearColorMapper
)
import bokeh.palettes as pt

# %%
from bokeh.io import output_notebook, push_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4b75c137-2ace-43f8-aa95-4408f5df87e3">Loading BokehJS ...</span>
#     </div>

# %%
suite_dict=pickle.load(open('suite_dict.pkl','rb'))
print(len(suite_dict.keys()))
source=ColumnDataSource(data=dict(x=list(suite_dict.keys()),y=list(suite_dict.values())))
# Out:
# 81

# %%
def get_barchart(source,suite_dict,loc,x_label,y_label,title="Cipher suite distribution"):
    values=np.array(list(suite_dict.values()))
    x_range_=list(suite_dict.keys())
    y_range_=(np.min(values),np.max(values))
    
    p=pt.inferno(len(x_range_))
    mapper=CategoricalColorMapper(palette=p,factors=x_range_)    
  
    plot=figure(x_range=x_range_, plot_height=550,plot_width=770,toolbar_location='above',\
                 title=title,x_axis_label=x_label,y_axis_label=y_label)
    
    plot.vbar(x='x',top='y',bottom=0,width=0.5,source=source,legend='Cipher suites',\
               fill_color={'field':'x','transform':mapper}) 
    plot.add_tools(HoverTool(tooltips=[("Cipher suite","@x"),("Count","@y")], show_arrow=False,\
                            point_policy='follow_mouse'))
                            
    plot.xaxis.major_label_orientation = np.pi/2  
    plot.legend.orientation = "horizontal"
    plot.legend.location = loc
    plot.xaxis.major_label_text_font_size ="7pt" 
    
    return plot

# %%
from collections import OrderedDict
try:
    del suite_dict['TLSv1.2']
except:
    pass 
sorted_suite_dict=OrderedDict(sorted(suite_dict.items(),key=lambda x:-x[1]))
#this is a list of tuples that can be made to dict.
source2=ColumnDataSource(data=dict(x=list(sorted_suite_dict.keys()),y=list(sorted_suite_dict.values())))
plot1=get_barchart(source2,sorted_suite_dict,"top_right",title="Cipher Suites vs Number of Websites",\
                   x_label="Cipher Suites",y_label="Number of websites") 
show(plot1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2d0d4994-5d19-43c9-a983-ea271acfebec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2d0d4994-5d19-43c9-a983-ea271acfebec");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2d0d4994-5d19-43c9-a983-ea271acfebec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2d0d4994-5d19-43c9-a983-ea271acfebec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0b5f24cc-1995-4bee-8f4e-1cdaba1b7bda":{"roots":{"references":[{"attributes":{},"id":"d9dd4880-7859-4966-bd81-f63f795fcd17","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Cipher Suites vs Number of Websites"},"id":"63fbf3b5-170b-4ce3-b6c9-089eebc9a2f9","type":"Title"},{"attributes":{"callback":null,"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"},"point_policy":"follow_mouse","show_arrow":false,"tooltips":[["Cipher suite","@x"],["Count","@y"]]},"id":"14cc5d24-6bd3-4a26-b153-5104f0b050d6","type":"HoverTool"},{"attributes":{"below":[{"id":"bb440c2c-c808-42ea-b10b-1e38640ee905","type":"CategoricalAxis"}],"left":[{"id":"5e6e1f40-9c5a-44ad-b544-504de25a48a2","type":"LinearAxis"}],"plot_height":550,"plot_width":770,"renderers":[{"id":"bb440c2c-c808-42ea-b10b-1e38640ee905","type":"CategoricalAxis"},{"id":"a56c0953-088a-46d6-ba27-7ed6bc7a49bb","type":"Grid"},{"id":"5e6e1f40-9c5a-44ad-b544-504de25a48a2","type":"LinearAxis"},{"id":"f31c1e9e-1b7c-449e-b511-306fc8f62e92","type":"Grid"},{"id":"edc8f684-54d6-49ed-90d1-b76a66a35809","type":"BoxAnnotation"},{"id":"fd81a22c-a211-4f07-9084-abb9f43f75ef","type":"Legend"},{"id":"7cbdce9b-5608-420c-9b27-0e07899fe4cb","type":"GlyphRenderer"}],"title":{"id":"63fbf3b5-170b-4ce3-b6c9-089eebc9a2f9","type":"Title"},"tool_events":{"id":"d9dd4880-7859-4966-bd81-f63f795fcd17","type":"ToolEvents"},"toolbar":{"id":"e3bd1265-1121-46b0-8700-7ee96fb492ec","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"ef78caa9-d6c3-4688-ba57-ffdec3b33a73","type":"FactorRange"},"y_range":{"id":"34492788-8a43-44f5-9548-bdf872c98621","type":"DataRange1d"}},"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"}},"id":"0ea35eec-974c-4f6e-9ee0-1a7521a89084","type":"PanTool"},{"attributes":{"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"},"ticker":{"id":"38d276b8-43d2-40b3-ace9-c300c1cab32a","type":"CategoricalTicker"}},"id":"a56c0953-088a-46d6-ba27-7ed6bc7a49bb","type":"Grid"},{"attributes":{"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"}},"id":"3d752106-3e90-4d06-815e-1cbfa1a814ae","type":"ResetTool"},{"attributes":{"data_source":{"id":"f5af8273-223a-45d1-bc67-3ded75c2d0fa","type":"ColumnDataSource"},"glyph":{"id":"8fdc7dcd-2c39-44e6-9ab5-395a4b4ec380","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"98bc1c7f-6504-4f4c-b26a-5bd69c43a257","type":"VBar"},"selection_glyph":null},"id":"7cbdce9b-5608-420c-9b27-0e07899fe4cb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"}},"id":"50cffd16-2657-4028-8538-703e7fc1e856","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"edc8f684-54d6-49ed-90d1-b76a66a35809","type":"BoxAnnotation"},{"attributes":{"items":[{"id":"21213d2a-e8b1-4191-a7a9-1c6564b085f5","type":"LegendItem"}],"orientation":"horizontal","plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"}},"id":"fd81a22c-a211-4f07-9084-abb9f43f75ef","type":"Legend"},{"attributes":{"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"}},"id":"fe2cc827-be3b-42c5-a921-de4a4174704f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"edc8f684-54d6-49ed-90d1-b76a66a35809","type":"BoxAnnotation"},"plot":{"id":"d5bdb54d-5177-4690-919b-2f0a483e3727","subtype":"Figure","type":"Plot"}},"id":"bc542ab7-b13e-4c04-81ba-6676bc0c9b81","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":" ...

# %%
cipher_suites_df=pd.read_csv('./crawl_cipher_suites.csv',header=None,names=["Company","CipherSuite","CDN"])
cipher_suites_df.ix[cipher_suites_df['CDN']==100,'CDN']= 5
cipher_suites_df.head()
suites=np.unique(cipher_suites_df['CipherSuite'].values)
print(suites)
grouped=cipher_suites_df.groupby(['CipherSuite'])

def get_group(suite):
    global grouped
    return grouped.get_group(suite)

mean_dict=grouped.mean().to_dict()['CDN']
sorted_mean_dict=OrderedDict(sorted(mean_dict.items(),key=lambda x: x[1]))
source3=ColumnDataSource(data=dict(x=list(sorted_mean_dict.keys()),y=list(sorted_mean_dict.values())))
plot3=get_barchart(source3,sorted_mean_dict,"top_left",x_label="CipherSuite",y_label="Mean CDT(seconds)",\
                   title="CipherSuite Vs Mean CDT") 
show(plot3)
# Out:
# ['DH+3DES' 'DH+AES' 'DH+AES256' 'DH+AESGCM' 'DH+CAMELLIA' 'DH+HIGH'
#  'ECDH+3DES' 'ECDH+AES128' 'ECDH+AES256' 'ECDH+AESGCM' 'ECDH+HIGH'
#  'ECDHE+ECDSA+3DES' 'ECDHE+ECDSA+AES128' 'ECDHE+ECDSA+AES256' 'RSA+3DES'
#  'RSA+AES' 'RSA+AESGCM' 'RSA+HIGH' 'http']
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1c4b55fc-49cb-4cbe-8dec-02d0acdc4959"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1c4b55fc-49cb-4cbe-8dec-02d0acdc4959");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1c4b55fc-49cb-4cbe-8dec-02d0acdc4959");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1c4b55fc-49cb-4cbe-8dec-02d0acdc4959' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f58d89b2-2363-43b5-b3fc-dd2f9e45ec0a":{"roots":{"references":[{"attributes":{"plot":null,"text":"CipherSuite Vs Mean CDT"},"id":"a108e4a4-edb3-462a-aa54-061bb6073b11","type":"Title"},{"attributes":{"label":{"value":"Cipher suites"},"renderers":[{"id":"e0d8b213-bb01-4e19-bcf9-026952a07d1c","type":"GlyphRenderer"}]},"id":"ce6599a3-787d-442c-92d2-9c16cf95595f","type":"LegendItem"},{"attributes":{"factors":["ECDH+HIGH","ECDH+AES128","ECDH+AESGCM","RSA+AES","RSA+HIGH","http","ECDH+AES256","RSA+AESGCM","RSA+3DES","DH+AES","ECDHE+ECDSA+AES128","DH+HIGH","ECDHE+ECDSA+AES256","DH+AESGCM","DH+AES256","ECDH+3DES","DH+CAMELLIA","DH+3DES","ECDHE+ECDSA+3DES"],"palette":["#000003","#08061F","#1A0B40","#32095D","#4A0B6A","#60136E","#781C6D","#8E2468","#A42C60","#BA3655","#CD4247","#DE5337","#ED6825","#F68012","#FB9906","#FBB318","#F7CF3A","#F1E968","#FCFEA4"]},"id":"fb328eea-5e8e-4aef-a131-02ad1946d672","type":"CategoricalColorMapper"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cbe55541-6261-4a25-8b6b-29656fa67dec","type":"PanTool"},{"id":"78687c16-26cc-4d69-8367-9681bfb7e14a","type":"WheelZoomTool"},{"id":"f063e11a-b640-4259-bab4-a1121115ad22","type":"BoxZoomTool"},{"id":"786f9e89-4850-4822-bcba-41ed6278a565","type":"SaveTool"},{"id":"43b96d49-7c7a-4117-a396-429a07ccc533","type":"ResetTool"},{"id":"bc3f2656-67c4-4b83-a342-5ef6e8981eb6","type":"HelpTool"},{"id":"9749d655-8f5c-44b5-8a25-8b546fe2100b","type":"HoverTool"}]},"id":"e539c5ca-3876-4a14-8895-24e60bc15068","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":["ECDH+HIGH","ECDH+AES128","ECDH+AESGCM","RSA+AES","RSA+HIGH","http","ECDH+AES256","RSA+AESGCM","RSA+3DES","DH+AES","ECDHE+ECDSA+AES128","DH+HIGH","ECDHE+ECDSA+AES256","DH+AESGCM","DH+AES256","ECDH+3DES","DH+CAMELLIA","DH+3DES","ECDHE+ECDSA+3DES"],"y":[0.38507796610169504,0.4461858757062142,0.4492353383458647,0.46147175141242913,0.4726613935969868,0.5632203007518802,0.6140301318267417,0.7691456685499056,2.394055932203389,4.12147627118644,4.154213370998118,4.175492278719398,4.1797781544256125,4.243432391713747,4.282665348399245,4.352139171374766,4.508384369114878,4.672359322033899,4.963532203389831]}},"id":"61a95684-93e6-4a21-ab92-aed1ea7c00c2","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["ECDH+HIGH","ECDH+AES128","ECDH+AESGCM","RSA+AES","RSA+HIGH","http","ECDH+AES256","RSA+AESGCM","RSA+3DES","DH+AES","ECDHE+ECDSA+AES128","DH+HIGH","ECDHE+ECDSA+AES256","DH+AESGCM","DH+AES256","ECDH+3DES","DH+CAMELLIA","DH+3DES","ECDHE+ECDSA+3DES"]},"id":"2b74a46e-f5bf-4c38-b9a7-b6c94cf29392","type":"FactorRange"},{"attributes":{},"id":"24b03e5f-bd7f-4d14-a6d7-4b149e1e18f8","type":"ToolEvents"},{"attributes":{"plot":{"id":"b4b8b5ec-ff23-4739-ae3d-3236e234aaa8","subtype":"Figure","type":"Plot"}},"id":"78687c16-26cc-4d69-8367-9681bfb7e14a","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"b4b8b5ec-ff23-4739-ae3d-3236e234aaa8","subtype":"Figure","type":"Plot"}},"id":"cbe55541-6261-4a25-8b6b-29656fa67dec","type":"PanTool"},{"attributes":{"axis_label":"Mean CDT(seconds)","formatter":{"id":"24abd92b-7e32-4b14-bfe9-0f7176a711b9","type":"BasicTickFormatter"},"plot":{"id":"b4b8b5ec-ff23-4739-ae3d-3236e234aaa8","subtype":"Figure","type":"Plot"},"ticker":{"id":"91d4f714-f46f-4926-826e-f3e18efa2d47","type":"BasicTicker"}},"id":"3afab5b3-176f-47b5-b298-82d664ae1e57","type":"LinearAxis"},{"attributes":{"below":[{"id":"25656e9d-eb7d-4f21-84ca-eb0b5e5daff3","type":"CategoricalAxis"}],"left":[{"id":"3afab5b3-176f-47b5-b298-82d664ae1e57","type":"LinearAxis"}],"plot_height":550,"plot_width":770,"renderers":[{"id":"25656e9d-eb7d-4f21-84ca-eb0b5e5daff3","type":"CategoricalAxis"},{"id":"5f3a1721-54ef-465d-8905-bf2ae9e7dd75","type":"Grid"},{"id":"3afab5b3-176f-47b5-b298-82d664ae1e57","type":"LinearAxis"},{"id":"e92f65f4-f86e-47a4-bb7e-e4d12fb219f5","type":"Grid"},{"id":"3d69ff87-758c-45b6-870c-987644cae694","type":"BoxAnnotation"},{ ...

# %%
cipher_suites_df=pd.read_csv('./crawl_cipher_suites.csv',header=None,names=["Company","CipherSuite","CDN"])
cipher_suites_df.ix[cipher_suites_df['CDN']==100,'CDN']= 5
cipher_suites_df.head()
suites=np.unique(cipher_suites_df['CipherSuite'].values)
print(suites)
grouped=cipher_suites_df.groupby(['CipherSuite'])

def get_group(suite):
    global grouped
    return grouped.get_group(suite)

median_dict=grouped.median().to_dict()['CDN']
sorted_median_dict=OrderedDict(sorted(median_dict.items(),key=lambda x: x[1]))
source6=ColumnDataSource(data=dict(x=list(sorted_median_dict.keys()),y=list(sorted_median_dict.values())))
plot6=get_barchart(source6,sorted_median_dict,"top_left",x_label="CipherSuite",y_label="Median CDT(seconds)",\
                   title="CipherSuite Vs Median CDT") 
show(plot6)
# Out:
# ['DH+3DES' 'DH+AES' 'DH+AES256' 'DH+AESGCM' 'DH+CAMELLIA' 'DH+HIGH'
#  'ECDH+3DES' 'ECDH+AES128' 'ECDH+AES256' 'ECDH+AESGCM' 'ECDH+HIGH'
#  'ECDHE+ECDSA+3DES' 'ECDHE+ECDSA+AES128' 'ECDHE+ECDSA+AES256' 'RSA+3DES'
#  'RSA+AES' 'RSA+AESGCM' 'RSA+HIGH' 'http']
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="397094f0-349f-4ebd-9302-d03e90f7273e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("397094f0-349f-4ebd-9302-d03e90f7273e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("397094f0-349f-4ebd-9302-d03e90f7273e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '397094f0-349f-4ebd-9302-d03e90f7273e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c6f7cd01-594f-4e06-bc4a-934f216b6cfc":{"roots":{"references":[{"attributes":{"fill_color":{"field":"x","transform":{"id":"d5fcfafb-469b-42c9-8f10-213459e40be0","type":"CategoricalColorMapper"}},"line_color":{"value":"#1f77b4"},"top":{"field":"y"},"width":{"value":0.5},"x":{"field":"x"}},"id":"5ad65f7d-eb1b-4f3c-8872-14af3f306b40","type":"VBar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cf19eafd-4b1c-4fc8-a2e3-7052eea5527c","type":"BoxAnnotation"},{"attributes":{"axis_label":"Median CDT(seconds)","formatter":{"id":"bc6bbf01-28d8-4e28-bf4f-13cbd3be7425","type":"BasicTickFormatter"},"plot":{"id":"4f30f1d0-942c-425a-867c-bf3783e1bc6a","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ab07f01-ad5e-4fc3-ab40-933d004509de","type":"BasicTicker"}},"id":"d10fd866-41e5-4b58-97fd-11c2dc00f86a","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":["RSA+HIGH","ECDH+HIGH","ECDH+AES128","RSA+AES","ECDH+AES256","ECDH+AESGCM","RSA+AESGCM","http","RSA+3DES","DH+3DES","DH+AES","DH+AES256","DH+AESGCM","DH+CAMELLIA","DH+HIGH","ECDH+3DES","ECDHE+ECDSA+3DES","ECDHE+ECDSA+AES128","ECDHE+ECDSA+AES256"],"y":[0.1399,0.1408,0.1415,0.1417,0.1494,0.1563,0.1666,0.2752,0.6917,5.0,5.0,5.0,5.0,5.0,5.0,5.0,5.0,5.0,5.0]}},"id":"0cfea6e2-d54b-48c7-9e6a-78adaa238701","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"y"},"width":{"value":0.5},"x":{"field":"x"}},"id":"20fd6f39-eeee-4f51-bc82-89aaa838d724","type":"VBar"},{"attributes":{"plot":{"id":"4f30f1d0-942c-425a-867c-bf3783e1bc6a","subtype":"Figure","type":"Plot"}},"id":"684fbebb-956b-4388-b9cd-e16479dcdf16","type":"HelpTool"},{"attributes":{},"id":"ec0d7186-231f-418e-b047-758f9cd201b2","type":"ToolEvents"},{"attributes":{"factors":["RSA+HIGH","ECDH+HIGH","ECDH+AES128","RSA+AES","ECDH+AES256","ECDH+AESGCM","RSA+AESGCM","http","RSA+3DES","DH+3DES","DH+AES","DH+AES256","DH+AESGCM","DH+CAMELLIA","DH+HIGH","ECDH+3DES","ECDHE+ECDSA+3DES","ECDHE+ECDSA+AES128","ECDHE+ECDSA+AES256"],"palette":["#000003","#08061F","#1A0B40","#32095D","#4A0B6A","#60136E","#781C6D","#8E2468","#A42C60","#BA3655","#CD4247","#DE5337","#ED6825","#F68012","#FB9906","#FBB318","#F7CF3A","#F1E968","#FCFEA4"]},"id":"d5fcfafb-469b-42c9-8f10-213459e40be0","type":"CategoricalColorMapper"},{"attributes":{"plot":null,"text":"CipherSuite Vs Median CDT"},"id":"f1de7c90-598e-4dab-a71b-c2d3500b9ce6","type":"Title"},{"attributes":{"label":{"value":"Cipher suites"},"renderers":[{"id":"8b4a5a0b-5c0d-45e5-bc4a-fe44dbfd01bb","type":"GlyphRenderer"}]},"id":"2ff5f9f3-c3fd-42f7-8dea-06cab7f9d287","type":"LegendItem"},{"attributes":{"overlay":{"id":"cf19eafd-4b1c-4fc8-a2e3-7052eea5527c","type":"BoxAnnotation"},"plot":{"id":"4f30f1d0-942c-425a-867c-bf3783e1bc6a","subtype":"Figure","type":"Plot"}},"id":"219f0652-5966-4561-b4db-c2a8ef743d67","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"4f30f1d0-942c-425a-867c-bf3783e1bc6a","subtype":"Figure","type":"Plot"}},"id":"cd62d91b-0545-4b2c-af6f-035da8ee2c5e","type":"SaveTool"},{"attributes":{},"id":"9ab07f01-ad5e-4fc3-ab40-933d004509de","type":"BasicTicker"},{"attributes":{"plot":{"id":"4f30f1d0-942c-425a-867c-bf3783e1bc6a","subtype":"Figure","type":"Plot"}},"id":"686f4be7-80d0-420f-b9a5-cc76ee92d338","type":"WheelZoomTool"},{"attributes":{"callback":null,"factors":["RSA+HIGH","ECDH+HIGH","ECDH+AES128","RSA+AES","ECDH+AES256","ECDH+AESGCM","RSA+AESGCM","http","RSA+3DES","DH+3DES","DH+AES","DH+AES256","DH+AESGCM","DH+CAMELLIA","DH+HIGH","ECDH+3DES","ECDHE+ECDSA+3DES","ECDHE+ECDSA+AES128","ECDHE+ECDSA+AES256"]},"id":"b8a148e6-4683-4818-aca9-a9971877d064" ...

# %%
min_dict=grouped.min().to_dict()['CDN']
sorted_min_dict=OrderedDict(sorted(min_dict.items(),key=lambda x: x[1]))
source4=ColumnDataSource(data=dict(x=list(sorted_min_dict.keys()),y=list(sorted_min_dict.values())))
plot2=get_barchart(source4,sorted_min_dict,"top_left",x_label="CipherSuite",y_label="Min CDT(seconds)",\
                   title="CipherSuite Vs Min CDT") 
show(plot2)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="da05cd27-dedd-4a1d-8c80-474444733f08"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("da05cd27-dedd-4a1d-8c80-474444733f08");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da05cd27-dedd-4a1d-8c80-474444733f08");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da05cd27-dedd-4a1d-8c80-474444733f08' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b1f8f483-f827-4be4-bee0-448287b0e756":{"roots":{"references":[{"attributes":{"plot":{"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"}},"id":"f678bd4c-3e10-4cfb-8f3f-00d613206bbf","type":"ResetTool"},{"attributes":{"plot":{"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"},"ticker":{"id":"434b4561-c6cc-4372-a579-5834812daa80","type":"CategoricalTicker"}},"id":"c463a49a-f78e-492d-81c4-ce0125ce2d06","type":"Grid"},{"attributes":{},"id":"89bb719e-5b90-4007-868d-c7fc9d47f2a1","type":"ToolEvents"},{"attributes":{"overlay":{"id":"a4f4b526-2720-4cd8-8c03-cd466df44399","type":"BoxAnnotation"},"plot":{"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"}},"id":"4bd85783-d45e-47eb-9ff8-af74d52216f2","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"f6893283-4820-43bd-a757-bbae16b4ad7b","type":"ColumnDataSource"},"glyph":{"id":"d1e9c0cf-a06a-4278-a0db-17c390d448c7","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6973e745-59e0-4c77-8c0e-a83932b59e94","type":"VBar"},"selection_glyph":null},"id":"ca19e040-a738-481f-963c-64f36bca3f02","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"a7d756be-146e-4033-880c-34d866bfd39e","type":"DataRange1d"},{"attributes":{},"id":"434b4561-c6cc-4372-a579-5834812daa80","type":"CategoricalTicker"},{"attributes":{"fill_color":{"field":"x","transform":{"id":"d5d58ed9-8f53-4f12-bafb-b3558bc0547a","type":"CategoricalColorMapper"}},"line_color":{"value":"#1f77b4"},"top":{"field":"y"},"width":{"value":0.5},"x":{"field":"x"}},"id":"d1e9c0cf-a06a-4278-a0db-17c390d448c7","type":"VBar"},{"attributes":{"plot":null,"text":"CipherSuite Vs Min CDT"},"id":"49189ee9-da20-419c-b75e-47cb0953d179","type":"Title"},{"attributes":{"below":[{"id":"e93f3fb1-c8ad-4111-b76c-f46858c26c09","type":"CategoricalAxis"}],"left":[{"id":"ec9e1352-d706-41a2-a7c8-20c738acc43c","type":"LinearAxis"}],"plot_height":550,"plot_width":770,"renderers":[{"id":"e93f3fb1-c8ad-4111-b76c-f46858c26c09","type":"CategoricalAxis"},{"id":"c463a49a-f78e-492d-81c4-ce0125ce2d06","type":"Grid"},{"id":"ec9e1352-d706-41a2-a7c8-20c738acc43c","type":"LinearAxis"},{"id":"f71943a4-9f49-4879-962e-9311cec19399","type":"Grid"},{"id":"a4f4b526-2720-4cd8-8c03-cd466df44399","type":"BoxAnnotation"},{"id":"41ee88b8-60be-407d-981d-b59c9f6795e4","type":"Legend"},{"id":"ca19e040-a738-481f-963c-64f36bca3f02","type":"GlyphRenderer"}],"title":{"id":"49189ee9-da20-419c-b75e-47cb0953d179","type":"Title"},"tool_events":{"id":"89bb719e-5b90-4007-868d-c7fc9d47f2a1","type":"ToolEvents"},"toolbar":{"id":"34542d79-ecf2-49dd-b017-bfb15cc6bbb1","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"8f8fb57e-cc85-4d0e-a832-d6438688f713","type":"FactorRange"},"y_range":{"id":"a7d756be-146e-4033-880c-34d866bfd39e","type":"DataRange1d"}},"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d386afb4-b0bb-49b8-a7bb-f14197322e54","type":"CategoricalTickFormatter"},{"attributes":{},"id":"2cc2e886-1993-44f6-be2a-7db19e32ed20","type":"BasicTicker"},{"attributes":{"plot":{"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"}},"id":"5bc8b7a2-d4e1-4d9b-8356-e786cb38800b","type":"SaveTool"},{"attributes":{"axis_label":"CipherSuite","formatter":{"id":"d386afb4-b0bb-49b8-a7bb-f14197322e54","type":"CategoricalTickFormatter"},"major_label_orientation":1.5707963267948966,"major_label_text_font_size":{"value":"7pt"},"plot":{"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"},"ticker":{"id":"434b4561-c6cc-4372-a579-5834812daa80","type":"CategoricalTicker"}},"id":"e93f3fb1-c8ad-4111-b76c-f46858c26c09","type":"CategoricalAxis"},{"attributes":{"dimension":1,"plot":{"id":"815aa8fa-d7c5-4600-b98f-baec7f455fe7","subtype":"Figure","type":"Plot"},"ticker":{"id":"2cc2e886-1993-44f6-be2a-7db19e32ed20","type":"BasicTicker"}},"id":"f71943a4-9f49-4879-962e-9311cec193 ...

# %%
cipher_suites_df=pd.read_csv('./crawl_cipher_suites.csv',header=None,names=["Company","CipherSuite","CDN"])
cipher_suites_df.ix[cipher_suites_df['CDN']==100,'CDN']= 5
cipher_suites_df['Company']=list(map(lambda x: 'www.'+x,cipher_suites_df['Company']))
companies=np.unique(cipher_suites_df['Company']).tolist()
print(len(companies))
#companies=list(map(lambda x: 'www.'+x,companies))
grouped_company=cipher_suites_df.groupby(['Company'])
scatter=None
select=None

def get_group(company_name):
    global grouped_company
    return grouped_company.get_group(company_name)

g_df=get_group('www.google.com')
ciphers=g_df['CipherSuite'].values
source=ColumnDataSource(data=dict(x=g_df['CipherSuite'].tolist(),y=g_df['CDN'].tolist()))

def update_plot(attr,old,new):
    global select,scatter,source
    selected_website=select.value
    scatter.title.text='Access times for'+ selected_website
    g_df=get_group(selected_website)
    source.data['x']=g_df['CipherSuite'].tolist()
    source.data['y']=g_df['CDN'].tolist()
    
     
select = Select(title="Website", value="www.google.com", options=companies)
select.on_change('value',update_plot)

def get_scatter():
    global source,scatter,ciphers
    x_range_=list(ciphers)

    values=source.data['y']
    y_range_=(np.min(values),np.max(values))
    
    p=pt.inferno(len(x_range_))
    mapper=CategoricalColorMapper(palette=list(p),factors=x_range_)    
  
    plot=figure(x_range=x_range_,plot_height=350,plot_width=500,toolbar_location='above',x_axis_label="CiphreSuites",\
               y_axis_label="Access Times")
    
    plot.title.text='Access times for www.google.com'
    plot.circle(x='x',y='y',source=source,size=12,\
               fill_color={'field':'x','transform':mapper}) 
    
    plot.add_tools(HoverTool(tooltips=[("Cipher suite","@x"),("AccessTime","@y")], show_arrow=False,\
                            point_policy='follow_mouse'))
                            
    plot.xaxis.major_label_orientation = np.pi/2  
    return plot
    
scatter=get_scatter()

layout=(column(row(scatter,widgetbox(select)),plot1,plot2,plot3))
curdoc().add_root(layout)
# Out:
# 532
